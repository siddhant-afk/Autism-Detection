# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.arff import loadarff

# %%
raw_data = loadarff("./Datasets/autism+screening+adult/Autism-Adult-Data.arff")
df1 = pd.DataFrame(raw_data[0])
df1.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'1'     b'1'     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'
# 1     b'1'     b'1'     b'0'     b'1'     b'0'     b'0'     b'0'     b'1'
# 2     b'1'     b'1'     b'0'     b'1'     b'1'     b'0'     b'1'     b'1'
# 3     b'1'     b'1'     b'0'     b'1'     b'0'     b'0'     b'1'     b'1'
# 4     b'1'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'1'
#
#   A9_Score A10_Score  ...  gender          ethnicity jundice  austim  \
# 0     b'0'      b'0'  ...    b'f'  b'White-European'   b'no'   b'no'
# 1     b'0'      b'1'  ...    b'm'          b'Latino'   b'no'  b'yes'
# 2     b'1'      b'1'  ...    b'm'          b'Latino'  b'yes'  b'yes'
# 3     b'0'      b'1'  ...    b'f'  b'White-European'   b'no'  b'yes'
# 4     b'0'      b'0'  ...    b'f'               b'?'   b'no'   b'no'
#
#       contry_of_res used_app_before result        age_desc   relation  \
# ...

# %%
len(df1)
# Out:
# 704

# %%
raw_data = loadarff("./Datasets/autistic+spectrum+disorder+screening+data+for+adolescent/Autism-Adolescent-Data.arff")
df2 = pd.DataFrame(raw_data[0])
df2.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'0'     b'0'     b'0'     b'1'     b'1'     b'1'     b'1'     b'1'
# 1     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 2     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 3     b'0'     b'1'     b'1'     b'1'     b'1'     b'1'     b'0'     b'1'
# 4     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'0'
#
#   A9_Score A10_Score  ...  gender          ethnicity jundice  austim  \
# 0     b'1'      b'0'  ...    b'm'        b'Hispanic'  b'yes'  b'yes'
# 1     b'1'      b'1'  ...    b'm'           b'Black'   b'no'   b'no'
# 2     b'1'      b'1'  ...    b'f'               b'?'   b'no'   b'no'
# 3     b'1'      b'0'  ...    b'f'  b'White-European'   b'no'   b'no'
# 4     b'0'      b'0'  ...    b'f'               b'?'   b'no'   b'no'
#
#        contry_of_res used_app_before result        age_desc     relation  \
# ...

# %%
len(df2)
# Out:
# 104

# %%
raw_data = loadarff("./Datasets/autistic+spectrum+disorder+screening+data+for+children/Autism-Child-Data.arff")
df3 = pd.DataFrame(raw_data[0])
df3.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 1     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 2     b'1'     b'1'     b'0'     b'0'     b'0'     b'1'     b'1'     b'1'
# 3     b'0'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'0'
# 4     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'
#
#   A9_Score A10_Score  ...  gender           ethnicity jundice austim  \
# 0     b'0'      b'0'  ...    b'm'           b'Others'   b'no'  b'no'
# 1     b'0'      b'0'  ...    b'm'  b'Middle Eastern '   b'no'  b'no'
# 2     b'0'      b'0'  ...    b'm'                b'?'   b'no'  b'no'
# 3     b'0'      b'1'  ...    b'f'                b'?'  b'yes'  b'no'
# 4     b'1'      b'1'  ...    b'm'           b'Others'  b'yes'  b'no'
#
#       contry_of_res used_app_before result       age_desc   relation Class/ASD
# ...

# %%
len(df3)
# Out:
# 292

# %% [markdown]
# ##### Adding Categorical Fields
#
# 0 - Adults
# 1 - Adolescent
# 2 - Children

# %%
df1["Age Group"] = 0
df1.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'1'     b'1'     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'
# 1     b'1'     b'1'     b'0'     b'1'     b'0'     b'0'     b'0'     b'1'
# 2     b'1'     b'1'     b'0'     b'1'     b'1'     b'0'     b'1'     b'1'
# 3     b'1'     b'1'     b'0'     b'1'     b'0'     b'0'     b'1'     b'1'
# 4     b'1'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'1'
#
#   A9_Score A10_Score  ...          ethnicity jundice  austim  \
# 0     b'0'      b'0'  ...  b'White-European'   b'no'   b'no'
# 1     b'0'      b'1'  ...          b'Latino'   b'no'  b'yes'
# 2     b'1'      b'1'  ...          b'Latino'  b'yes'  b'yes'
# 3     b'0'      b'1'  ...  b'White-European'   b'no'  b'yes'
# 4     b'0'      b'0'  ...               b'?'   b'no'   b'no'
#
#       contry_of_res used_app_before result        age_desc   relation  \
# 0  b'United States'           b'no'    6.0  b'18 and more'    b'Self'
# ...

# %%
df2["Age Group"] = 1
df2.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'0'     b'0'     b'0'     b'1'     b'1'     b'1'     b'1'     b'1'
# 1     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 2     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'
# 3     b'0'     b'1'     b'1'     b'1'     b'1'     b'1'     b'0'     b'1'
# 4     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'0'
#
#   A9_Score A10_Score  ...          ethnicity jundice  austim  \
# 0     b'1'      b'0'  ...        b'Hispanic'  b'yes'  b'yes'
# 1     b'1'      b'1'  ...           b'Black'   b'no'   b'no'
# 2     b'1'      b'1'  ...               b'?'   b'no'   b'no'
# 3     b'1'      b'0'  ...  b'White-European'   b'no'   b'no'
# 4     b'0'      b'0'  ...               b'?'   b'no'   b'no'
#
#        contry_of_res used_app_before result        age_desc     relation  \
# 0         b'Austria'           b'no'    6.0  b'12-16 years'    b'Parent'
# ...

# %%
df3["Age Group"] = 2
df3.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 1     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 2     b'1'     b'1'     b'0'     b'0'     b'0'     b'1'     b'1'     b'1'
# 3     b'0'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'0'
# 4     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'
#
#   A9_Score A10_Score  ...           ethnicity jundice austim  \
# 0     b'0'      b'0'  ...           b'Others'   b'no'  b'no'
# 1     b'0'      b'0'  ...  b'Middle Eastern '   b'no'  b'no'
# 2     b'0'      b'0'  ...                b'?'   b'no'  b'no'
# 3     b'0'      b'1'  ...                b'?'  b'yes'  b'no'
# 4     b'1'      b'1'  ...           b'Others'  b'yes'  b'no'
#
#       contry_of_res used_app_before result       age_desc   relation  \
# 0         b'Jordan'           b'no'    5.0  b'4-11 years'  b'Parent'
# ...

# %%
merged_df = pd.merge(df1,df2,how="outer")
merged_df = pd.merge(merged_df,df3,how="outer")
# merged_df.reset_index(inplace=True)
merged_df.head()
# Out:
#   A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0     b'1'     b'1'     b'1'     b'1'     b'0'     b'0'     b'1'     b'1'
# 1     b'1'     b'1'     b'0'     b'1'     b'0'     b'0'     b'0'     b'1'
# 2     b'1'     b'1'     b'0'     b'1'     b'1'     b'0'     b'1'     b'1'
# 3     b'1'     b'1'     b'0'     b'1'     b'0'     b'0'     b'1'     b'1'
# 4     b'1'     b'0'     b'0'     b'0'     b'0'     b'0'     b'0'     b'1'
#
#   A9_Score A10_Score  ...          ethnicity jundice  austim  \
# 0     b'0'      b'0'  ...  b'White-European'   b'no'   b'no'
# 1     b'0'      b'1'  ...          b'Latino'   b'no'  b'yes'
# 2     b'1'      b'1'  ...          b'Latino'  b'yes'  b'yes'
# 3     b'0'      b'1'  ...  b'White-European'   b'no'  b'yes'
# 4     b'0'      b'0'  ...               b'?'   b'no'   b'no'
#
#       contry_of_res used_app_before result        age_desc   relation  \
# 0  b'United States'           b'no'    6.0  b'18 and more'    b'Self'
# ...

# %%
len(merged_df)
# Out:
# 1100

# %%
merged_df["Age Group"].value_counts()
# Out:
# Age Group
# 0    704
# 2    292
# 1    104
# Name: count, dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
data = merged_df

# %%
print("No. of records : ", len(data.index))
print("No. of individuals diagnosed with Autism : ", len(data[data["Class/ASD"] == b"YES"]))
print("No. of individuals not diagnosed with Autism : ",len(data[data["Class/ASD"] == b"NO"]))
print(f'Percentage of individuals diagnosed with Autism :  {len(data[data["Class/ASD"] == b"YES"])/len(data.index) * 100:.2f}%')
# Out:
# No. of records :  1100
# No. of individuals diagnosed with Autism :  393
# No. of individuals not diagnosed with Autism :  707
# Percentage of individuals diagnosed with Autism :  35.73%

# %%
print("No. of Null fields:\n",data.isna().sum())
# Out:
# No. of Null fields:
#  A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                6
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# Age Group          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         1100 non-null   object
#  1   A2_Score         1100 non-null   object
#  2   A3_Score         1100 non-null   object
#  3   A4_Score         1100 non-null   object
#  4   A5_Score         1100 non-null   object
#  5   A6_Score         1100 non-null   object
#  6   A7_Score         1100 non-null   object
#  7   A8_Score         1100 non-null   object
#  8   A9_Score         1100 non-null   object
#  9   A10_Score        1100 non-null   object
#  10  age              1094 non-null   float64
#  11  gender           1100 non-null   object
#  12  ethnicity        1100 non-null   object
#  13  jundice          1100 non-null   object
#  14  austim           1100 non-null   object
#  15  contry_of_res    1100 non-null   object
# ...

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
sns.violinplot(x="jundice", y="result", hue="austim", data=data, split=True,
                inner="quart", palette={b'yes': "r", b'no': "b"})
sns.despine(left=True)

# %%
sns.violinplot(x="jundice", y="result", hue="Class/ASD", data=data, split=True,
                inner="quart", palette={b'YES': "r", b'NO': "b"})
sns.despine(left=True)

# %%
sns.violinplot(x="gender", y="result", hue="Class/ASD", data=data, split=True,
                inner="quart", palette={b'YES': "r", b'NO': "b"})
sns.despine(left=True)

# %%
data["ethnicity"].value_counts()
# Out:
# ethnicity
# b'White-European'     381
# b'Asian'              185
# b'?'                  144
# b'Middle Eastern '    128
# b'Black'               65
# b'South Asian'         60
# b'Others'              56
# b'Latino'              33
# b'Hispanic'            25
# b'Pasifika'            14
# b'Turkish'              8
# b'others'               1
# Name: count, dtype: int64

# %%
data["age_desc"].value_counts()
# Out:
# age_desc
# b'18 and more'    704
# b'4-11 years'     292
# b'12-16 years'     97
# b'12-15 years'      7
# Name: count, dtype: int64

# %%
data["relation"].value_counts()
# Out:
# relation
# b'Self'                        571
# b'Parent'                      300
# b'?'                           144
# b'Relative'                     53
# b'Health care professional'     23
# b'Others'                        8
# b'self'                          1
# Name: count, dtype: int64

# %%
data["contry_of_res"].value_counts()
# Out:
# contry_of_res
# b'United States'           167
# b'United Kingdom'          155
# b'India'                   130
# b'New Zealand'              95
# b'United Arab Emirates'     90
#                           ...
# b'Aruba'                     1
# b'Angola'                    1
# b'Czech Republic'            1
# b'Cyprus'                    1
# b'Bhutan'                    1
# Name: count, Length: 89, dtype: int64
